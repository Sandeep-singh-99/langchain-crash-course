# %%
import os
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)

# %% [markdown]
# Define the prompt template

# %%
template = """
You are a helpful AI assistant. Your task is to answer the user's question to the best of your ability.

User's question: {question}

Please provide a clear and concise answer:
"""

prompt = PromptTemplate(template=template, input_variables=["question"])

# %% [markdown]
# Create the LLMChain

# %%
qa_chain = prompt | llm

# %% [markdown]
# Define the get_answer function

# %%
def get_answer(question):
    """
    Get an answer to the given question using the QA chain.
    """
    # "qa_chain" is a RunnableSequence object produced by the pipe operator, which
    # isn't directly callable. Use its `run` method to execute the sequence.
    # You can either supply a dict of variables or keyword arguments.
    response = qa_chain.invoke({"question": question})
    return response

# %% [markdown]
# Interactive cell for user questions

# %%
user_question = input("Enter your question: ")
user_answer = get_answer(user_question)
print(f"Answer: {user_answer.content}")
# Out:
# Answer: ReactJS was first launched by Facebook on **May 29, 2013**.
