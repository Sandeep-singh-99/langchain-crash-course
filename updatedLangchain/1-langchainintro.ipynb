# %% [markdown]
# # Langchain Version V1

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

def get_weather(city: str) -> str:
    """Get the weather for a city."""
    return f"The weather in {city} is sunny."

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", model_kwargs={"tools": [get_weather]}, temperature=0.9)

llm
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash', temperature=0.9, client=<google.genai.client.Client object at 0x00000186BB438350>, default_metadata=(), model_kwargs={'tools': [<function get_weather at 0x00000186F1BC1C60>]})

# %%
response = llm.invoke("What is the weather in New York?")

# %%
response
# Out:
# AIMessage(content='I cannot provide real-time weather updates as my information is not live.\n\nHowever, you can easily get the most up-to-date weather for New York by:\n\n*   **Checking a weather website:** Such as [weather.com](https://www.weather.com/), AccuWeather, or the National Weather Service (NWS).\n*   **Using a weather app** on your smartphone.\n*   **Searching "weather in New York"** on Google or your preferred search engine.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e5386-26f7-7712-ae3d-3508829204a7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 472, 'total_tokens': 481, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 367}})
