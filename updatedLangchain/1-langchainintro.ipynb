# %% [markdown]
# # Langchain Version V1

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.tools import tool

@tool
def get_weather(city: str) -> str:
    """Get the weather for a city."""
    return f"The weather in {city} is sunny."

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.9)

llm
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash', temperature=0.9, client=<google.genai.client.Client object at 0x00000186F2069A90>, default_metadata=(), model_kwargs={})

# %%
llm_with_tools = llm.bind_tools([get_weather])

# %%
response = llm_with_tools.invoke("What is the weather in New York?")

# %%
response
# Out:
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather', 'arguments': '{"city": "New York"}'}, '__gemini_function_call_thought_signatures__': {'552a9afb-5c6a-422a-98bc-74cda0451b53': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e538c-aeb4-7901-9999-d9813b0fdc72-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'New York'}, 'id': '552a9afb-5c6a-422a-98bc-74cda0451b53', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 61, 'total_tokens': 109, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 45}})

# %%
response.tool_calls
# Out:
# [{'name': 'get_weather',
#   'args': {'city': 'New York'},
#   'id': '552a9afb-5c6a-422a-98bc-74cda0451b53',
#   'type': 'tool_call'}]
