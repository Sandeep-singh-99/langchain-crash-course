# %% [markdown]
# # Multimodal RAG (PDF With Images)

# %%
import fitz
from langchain_core.documents import Document
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import torch
import numpy as np
from langchain.chat_models import init_chat_model
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import HumanMessage
from sklearn.metrics.pairwise import cosine_similarity
import os
import base64
import io
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS

# %%
import os
from dotenv import load_dotenv
from transformers import CLIPProcessor, CLIPModel
from langchain.chat_models import init_chat_model

# 1. Load your environment variables
load_dotenv()

# 2. Set up your Groq API Key (No OpenAI keys needed)
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# 3. Initialize CLIP locally for your unified embeddings (Runs on your machine)
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
clip_model.eval()

# 4. Initialize your Groq LLM for all text processing and reasoning
# (We will use Llama 3.3 70B as the powerhouse model)
llm = init_chat_model(
    model="llama-3.3-70b-versatile",
    model_provider="groq",
    temperature=0.0
)

print("Setup Complete: Local CLIP initialized for embeddings & Groq set as the sole LLM provider.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 13
#       9 # 2. Set up your Groq API Key (No OpenAI keys needed)
#      10 os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
#      11
#      12 # 3. Initialize CLIP locally for your unified embeddings (Runs on your machine)
# ---> 13 clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
#      14 clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
#      15 clip_model.eval()
#      16
#
# File c:\Users\sk335\OneDrive\Documents\Coding\PythonProjects\langchain-and-langgraph\.venv\Lib\site-packages\transformers\utils\import_utils.py:1944, in DummyObject.__getattribute__(cls, key)
#    1942 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    1943     return super().__getattribute__(key)
# ...
